# %%
! pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
! pip install openpyxl

# %%
df = pd.read_excel('D:\GUVI_Capstone_Project\Census_data\census_2011 (1).xlsx',header=0)
df.head()
# Out:
#    District code         State name District name  Population      Male  \
# 0              1  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR        Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR        Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR         Punch         NaN  251899.0
#
#      Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %% [markdown]
# #### Shape of the dataset:

# %%
df.shape
# Out:
# (640, 118)

# %% [markdown]
# The dataset contains 640 rows and 118 columns.

# %% [markdown]
# #### Summary of the dataset :

# %%
# Displaying summary for a dataframe

df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.100000e+02  6.100000e+02  6.070000e+02  6.040000e+02
# mean      320.500000  1.852620e+06  9.685726e+05  9.139882e+05  1.190550e+06
# std       184.896367  1.435578e+06  7.926455e+05  7.479293e+05  1.050630e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.148625e+05  4.180382e+05  3.986990e+05  4.796545e+05
# 50%       320.500000  1.557367e+06  7.939620e+05  7.556020e+05  9.793575e+05
# 75%       480.250000  2.565248e+06  1.318615e+06  1.253832e+06  1.602260e+06
# max       640.000000  1.000978e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.090000e+02     6.130000e+02  6.050000e+02  6.170000e+02
# mean    6.739088e+05     5.129481e+05  3.177854e+05  1.624509e+05
# std     5.683384e+05     4.801441e+05  3.172010e+05  1.625607e+05
# ...

# %% [markdown]
# ### Check Datatypes in the dataset

# %%
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: float64(115), int64(1), object(2)
# memory usage: 590.1+ KB

# %% [markdown]
# ### Check for all columns

# %%
df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %% [markdown]
# ## Task 1 : Remane the Column names

# %%
def rename_columns(df):
    column_mapping = {
        'State name': 'State/UT',
        'District name': 'District',
        'Male_Literate': 'Literate_Male',
        'Female_Literate': 'Literate_Female',
        'Rural_Households': 'Households_Rural',
        'Urban_ Households': 'Households_Urban',
        'Age_Group_0_29': 'Young_and_Adult',
        'Age_Group_30_49': 'Middle_Aged',
        'Age_Group_50': 'Senior_Citizen',
        'Age not stated': 'Age_Not_Stated'
    }
    print(f"Original columns: {df.columns.tolist()}")
    df.rename(columns=column_mapping, inplace=True)
    print(f"Renamed columns: {df.columns.tolist()}")
    return df

# %%
df = rename_columns(df)
# Out:
# Original columns: ['District code', 'State name', 'District name', 'Population', 'Male', 'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST', 'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains', 'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households', 'Housholds_with_Electric_Lighting', 'Households_with_Internet', 'Households_with_Computer', 'Rural_Households', 'Urban_Households', 'Households', 'Below_Primary_Education', 'Primary_Education', 'Middle_Education', 'Secondary_Education', 'Higher_Education', 'Graduate_Education', 'Other_Education', 'Literate_Education', 'Illiterate_Education', 'Total_Education', 'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50', 'Age not stated', 'Households_with_Bicycle', 'Households_with
# ...

# %%
df.head()
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR       Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR       Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR        Punch         NaN  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %% [markdown]
# ## Task 2: Rename State/UT Names

# %%
def rename_state_ut_names(df):
    if 'State/UT' in df.columns:
        df['State/UT'] = df['State/UT'].apply(lambda x: ' '.join([word.capitalize() if word != 'and' else word.lower() for word in x.split()]))
        print("State/UT names standardized successfully")
    else:
        print("Error: 'State/UT' column not found in DataFrame")
    return df

# %%
df = rename_state_ut_names(df)
# Out:
# State/UT names standardized successfully

# %%
df.head(5)
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  Jammu And Kashmir      Kupwara    870354.0  474190.0
# 1              2  Jammu And Kashmir       Badgam    753745.0       NaN
# 2              3  Jammu And Kashmir  Leh(Ladakh)    133487.0   78971.0
# 3              4  Jammu And Kashmir       Kargil    140802.0       NaN
# 4              5  Jammu And Kashmir        Punch         NaN  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %% [markdown]
# ### Define numerical & Categorical columns

# %%
numeric_features =[feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

#Print columns
print('We have {} numerical features : {}'.format(len(numeric_features),numeric_features))
print('We have {} categorical features : {}'.format(len(categorical_features),categorical_features))
# Out:
# We have 116 numerical features : ['District code', 'Population', 'Male', 'Female', 'Literate', 'Literate_Male', 'Literate_Female', 'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST', 'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains', 'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households', 'Housholds_with_Electric_Lighting', 'Households_with_Internet', 'Households_with_Computer', 'Households_Rural', 'Urban_Households', 'Households', 'Below_Primary_Education', 'Primary_Education', 'Middle_Education', 'Secondary_Education', 'Higher_Education', 'Graduate_Education', 'Other_Education', 'Literate_Education', 'Illiterate_Education', 'Total_Education', 'Young_and_Adult', 'Middle_Aged', 'Senior_Citizen', 'Age_Not_Stated', 'Households_with_Bicycle', 'Households_with_Car_Jeep_Van', '
# ...

# %%
df[numeric_features].head(5)
# Out:
#    District code  Population      Male    Female  Literate  Literate_Male  \
# 0              1    870354.0  474190.0  396164.0  439654.0       282823.0
# 1              2    753745.0       NaN  355704.0  335649.0       207741.0
# 2              3    133487.0   78971.0   54516.0   93770.0        62834.0
# 3              4    140802.0       NaN   63017.0       NaN        56301.0
# 4              5         NaN  251899.0  224936.0  261724.0       163333.0
#
#    Literate_Female      SC  Male_SC  Female_SC  ...  \
# 0         156831.0  1048.0   1046.0        2.0  ...
# 1         127908.0     NaN    343.0       25.0  ...
# 2          30936.0   488.0    444.0       44.0  ...
# 3          29935.0    18.0     12.0        6.0  ...
# 4          98391.0   556.0    406.0        NaN  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# 1                         126.0                         562.0
# ...

# %%
df[categorical_features].head(5)
# Out:
#             State/UT     District
# 0  Jammu And Kashmir      Kupwara
# 1  Jammu And Kashmir       Badgam
# 2  Jammu And Kashmir  Leh(Ladakh)
# 3  Jammu And Kashmir       Kargil
# 4  Jammu And Kashmir        Punch

# %% [markdown]
# ## Task -3 New State/UT formation with encoding handling

# %% [markdown]
# - In 2014 Telangana was formed after it split from Andhra Pradesh, The districts that were included in Telangana are stored in Data/Telangana.txt . Read the text file and Rename the State/UT From “Andhra Pradesh” to “Telangana” for the given districts.
#
# - In 2019 Ladakh was formed after it split from Jammu and Kashmir, which included the districts Leh and Kargil.  Rename the State/UT From “Jammu and Kashmir” to “Ladakh” for the given districts.

# %%
! pip install python-docx

# %%
import docx

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return fullText


telanganaDistric = getText('D:\GUVI_Capstone_Project\Census_data\Telangana (1).docx')

print(telanganaDistric)
# Out:
# ['Adilabad', 'Nizamabad', 'Karimnagar', 'Medak', 'Hyderabad', 'Rangareddy', 'Mahbubnagar', 'Nalgonda', 'Warangal', 'Khammam']

# %%
def setTelangana():
    for  i in telanganaDistric :
        df.loc[ df['District'] == i, 'State/UT'] ='Telangana'

setTelangana()

ladakhDistric= [
    "Leh(Ladakh)",
    "Kargil"
]

def setLadakh():
    for  i in ladakhDistric :
        df.loc[ df['District'] == i, 'State/UT'] ='Ladakh'


setLadakh()

df[df['State/UT'].str.contains('Ladakh')]
# Out:
#    District code State/UT     District  Population     Male   Female  \
# 2              3   Ladakh  Leh(Ladakh)    133487.0  78971.0  54516.0
# 3              4   Ladakh       Kargil    140802.0      NaN  63017.0
#
#    Literate  Literate_Male  Literate_Female     SC  ...  \
# 2   93770.0        62834.0          30936.0  488.0  ...
# 3       NaN        56301.0          29935.0   18.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 2                          46.0                         122.0
# 3                          27.0                         114.0
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 2                           15.0                           22.0
# 3                           12.0                           18.0
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 2                            NaN                           20.0
# 3                           30.0                           19.0
#
# ...

# %%
print(((df.isnull() | df.isna()).sum() * 100 / df.index.size).round(2))
# Out:
# District code                    0.00
# State/UT                         0.00
# District                         0.00
# Population                       4.69
# Male                             4.69
#                                  ...
# Power_Parity_Rs_330000_425000    5.16
# Power_Parity_Rs_425000_545000    4.69
# Power_Parity_Rs_330000_545000    3.59
# Power_Parity_Above_Rs_545000     4.69
# Total_Power_Parity               5.00
# Length: 118, dtype: float64

# %% [markdown]
# ## Task 4 : Find and Process Missing Data

# %%
df['Population'].fillna(value=df['Male']+df['Female'],inplace=True)

df['Female'].fillna(value=df['Population'] - df['Male'], inplace=True)

df['Male'].fillna(value=df['Population'] - df['Female'], inplace=True)

df['Literate'].fillna(value=df['Literate_Male']+df['Literate_Female'],inplace=True)


df['Literate_Male'].fillna(value=df['Literate'] - df['Literate_Female'], inplace=True)

df['Literate_Female'].fillna(value=df['Literate'] - df['Literate_Male'], inplace=True)

df['ST'].fillna(value=df['Male_ST']+df['Female_ST'],inplace=True)

df['Male_ST'].fillna(value=df['ST'] -df['Female_ST'], inplace=True)

df['Female_ST'].fillna(value=df['ST'] -df['Male_ST'], inplace=True)

df['Workers'].fillna(value=df['Male_Workers']+df['Female_Workers'],inplace=True)

df['Male_Workers'].fillna(value=df['Workers'] -df['Female_Workers'], inplace=True)

df['Female_Workers'].fillna(value=df['Workers'] -df['Male_Workers'], inplace=True)

# %%
print(((df.isnull() | df.isna()).sum() * 100 / df.index.size).round(2))
# Out:
# District code                    0.00
# State/UT                         0.00
# District                         0.00
# Population                       0.16
# Male                             0.16
#                                  ...
# Power_Parity_Rs_330000_425000    5.16
# Power_Parity_Rs_425000_545000    4.69
# Power_Parity_Rs_330000_545000    3.59
# Power_Parity_Above_Rs_545000     4.69
# Total_Power_Parity               5.00
# Length: 118, dtype: float64

# %%
# Replace missing data in each column with the mean of that column
df_filled = df.fillna(df.mean(numeric_only=True))

# Verify that missing values have been filled
missing_values_after = df_filled.isnull().sum()

missing_values_after
# Out:
# District code                    0
# State/UT                         0
# District                         0
# Population                       0
# Male                             0
#                                 ..
# Power_Parity_Rs_330000_425000    0
# Power_Parity_Rs_425000_545000    0
# Power_Parity_Rs_330000_545000    0
# Power_Parity_Above_Rs_545000     0
# Total_Power_Parity               0
# Length: 118, dtype: int64

# %% [markdown]
# ### Replace missing data in each column with the mean of that column

# %%
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:  # Only calculate the mean for numeric columns
        mean_value = df[column].mean()
        df[column].fillna(mean_value, inplace=True)

# Verify that missing values have been filled
missing_values_after = df.isnull().sum()

missing_values_after
# Out:
# District code                    0
# State/UT                         0
# District                         0
# Population                       0
# Male                             0
#                                 ..
# Power_Parity_Rs_330000_425000    0
# Power_Parity_Rs_425000_545000    0
# Power_Parity_Rs_330000_545000    0
# Power_Parity_Above_Rs_545000     0
# Total_Power_Parity               0
# Length: 118, dtype: int64

# %%
# Calculate the mean value of the 'Male' column, excluding NaNs
mean_male = df['Male'].mean()

# Replace missing values in the 'Male' column with the mean value
df['Male'].fillna(mean_male, inplace=True)

# Verify that missing values have been filled in the 'Male' column
missing_values_male_after = df['Male'].isnull().sum()

missing_values_male_after
# Out:
# 0

# %%
# Calculate the mean value of the 'Female' column, excluding NaNs
mean_female = df['Female'].mean()

# Replace missing values in the 'Female' column with the mean value
df['Female'].fillna(mean_female, inplace=True)

# Verify that missing values have been filled in the 'female' column
missing_values_male_after = df['Female'].isnull().sum()

missing_values_male_after
# Out:
# 0

# %%
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            Jammu And Kashmir                    Kupwara
# 1                2            Jammu And Kashmir                     Badgam
# 2                3                       Ladakh                Leh(Ladakh)
# 3                4                       Ladakh                     Kargil
# 4                5            Jammu And Kashmir                      Punch
# ..             ...                          ...                        ...
# 635            636                  Pondicherry                       Mahe
# 636            637                  Pondicherry                   Karaikal
# 637            638  Andaman And Nicobar Islands                   Nicobars
# 638            639  Andaman And Nicobar Islands  North  AND Middle Andaman
# 639            640  Andaman And Nicobar Islands              South Andaman
#
# ...

# %% [markdown]
# ### Resolve all the Nan value & missing value issue

# %% [markdown]
# ## Task 5 : Save The Data to MongoDB

# %%
# !python -m pip install "pymongo[srv]"

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://sashikantaraja1966:12345@cluster0.ndy0rxz.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
def insertToMongodb():
    if client['test'].list_collection_names != "" :
        myCollection = client['test']
        if myCollection['census'].find_one() != "":
            myCollection['census'].insert_many(df.to_dict("records"))
        else:
            print('No Collection inside DataBase')
            myCollection = client['census']
            myCollection['census'].insert_many(df.to_dict("records"))
    else:
        print('No DataBase')
        dp = client['test']
        myCollection = client['census']
        myCollection['census'].insert_many(df.to_dict("records"))
        print('The insertion successfull!')

insertToMongodb()

# %% [markdown]
# ## Task 6: Database connection to Mysql & Upload the data to Mysql from MongoDB

# %%
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host ="localhost",
    user='root',
    password ="",
    connection_timeout=300
)
print(mydb)
mycursor = mydb.cursor(buffered=True)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\91797\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Lost connection to MySQL server at 'reading initial communication packet', system error: 0
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[29], line 2
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(
#       3     host ="localhost",
#       4     user='root',
#       5     password ="",
#       6     connection_timeout=300
#       7 )
#       8 print(mydb)
# ...

# %%
def creatdb(df):
    mycursor.execute('CREATE DATABASE IF NOT EXISTS census_db')

    listOfColumns = list()

    for i in df.columns:
        if i == 'District code':
            listOfColumns.append('District_Code INT PRIMARY KEY')
        elif i == "State/UT":
            listOfColumns.append('State_UT VARCHAR(50)')
        elif i == "District":
            listOfColumns.append('District VARCHAR(50)')
        elif i == "Households_with_TV_Computer_Laptop_Telephone_mobile_phone_and_Scooter_Car":
            listOfColumns.append("Households_TV_Computer_Laptop_Telephone_mobile_phone_Scooter_Car INT")
        elif i == "Type_of_latrine_facility_Night_soil_disposed_into_open_drain_Households":
            listOfColumns.append("Type_of_latrine_facility_Night_soil_disposed_into_open_drain INT")
        elif i == "Type_of_latrine_facility_Flush_pour_flush_latrine_connected_to_other_system_Households":
            listOfColumns.append("Type_of_latrine_Flush_pour_connected_to_other_system_Households INT")
        elif i == "Not_having_latrine_facility_within_the_premises_Alternative_source_Open_Households":
            listOfColumns.append("Not_having_latrine_within_premises_Other_source_Open_Households INT")
        elif i == "Main_source_of_drinking_water_Handpump_Tubewell_Borewell_Households":
            listOfColumns.append("Source_of_drinking_water_Handpump_Tubewell_Borewell_Households INT")
        elif i == "Main_source_of_drinking_water_Other_sources_Spring_River_Canal_Tank_Pond_Lake_Other_sources__Households":
            listOfColumns.append("Drinking_water_Spring_River_Canal_Tank_Pond_Lake_Other_Household INT")
        else:
            listOfColumns.append(f'{i} INT')

    mycursor.execute(f'CREATE TABLE census_db.census_2011 ({", ".join(listOfColumns)})')
    mydb.commit()

creatdb(df)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\91797\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Lost connection to MySQL server during query
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[50], line 31
# ...

# %%
def get_columns(table_name):
    mycursor.execute(f"DESCRIBE {table_name}")
    table_columns = []
    #print(mycursor)
    for i in mycursor:
        table_columns.append(i[0])

    return tuple(table_columns)

table_columns = get_columns('Census_db.census_2011')

print(table_columns)
# Out:
# ('District_Code', 'State_UT', 'District', 'Population', 'Male', 'Female', 'Literate', 'Literate_Male', 'Literate_Female', 'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST', 'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains', 'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households', 'Housholds_with_Electric_Lighting', 'Households_with_Internet', 'Households_with_Computer', 'Households_Rural', 'Urban_Households', 'Households', 'Below_Primary_Education', 'Primary_Education', 'Middle_Education', 'Secondary_Education', 'Higher_Education', 'Graduate_Education', 'Other_Education', 'Literate_Education', 'Illiterate_Education', 'Total_Education', 'Young_and_Adult', 'Middle_Aged', 'Senior_Citizen', 'Age_Not_Stated', 'Households_with_Bicycle', 'Households_with_Car_Jeep_Van', 'Household
# ...

# %%
def dbinsert_data(clients, df, table_columns):
    placeholders = ", ".join(["%s"] * len(table_columns))
    columns = ", ".join(table_columns)

    data = []

    for i in range(1,len(df)+1):
        for j in clients.find({'District code':i}):
            data.append(tuple(j.values())[1:])

    try :
        query = f'INSERT INTO Census_DB.Census_2011 ({columns}) VALUES ({placeholders})'
        mycursor.executemany(query, data)
    except Exception as e:
        print(e)

    mydb.commit()
my_dbs = client['test']
mycolle = my_dbs['census']
dbinsert_data(mycolle, df, table_columns)
# Out:
# 1054 (42S22): Unknown column 'nan' in 'field list'
